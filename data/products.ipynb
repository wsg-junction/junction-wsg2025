# %%
import json

with open("products.json") as f:
    products = json.load(f)
products = products["products"]

old_products = {}
with open("products_old.json") as f:
    old = json.load(f)
    for p in old:
        if "salesUnitGtin" not in p:
            continue
        id = p["salesUnitGtin"]
        old_products[id] = p

# %%
def map_product(product):
    to_delete = [
        "availabilityNotificationActive",
        "countriesOfOrigin",
        "favorite",
        "frozenProduct",
        "icons",
        "inOrderTemplate",
        "lowestPriceInComparison",
        "crossSellingProducts",
        "myAssortment",
        "netPriceFound",
        "novelty",
        "pikatukkuStock",
        "pikatukkuWebShopProduct",
        "stock",
        "taxPercentage",
        "taxPercentageCatalogPrice",
        "pk",
        "code",
        "priceWithTax",
        "baseUnit",
        "allowedLotSize",
        "comparisonPrice",
        "comparisonUnit",
        "purchasable",
        "campaign",
        "similarProducts",
        "sizeInBaseUnits",
        "sponsored",
        "unit",
        "url",
        "images",
        "name",
        "description",
        "discount",
        "strikeThroughPrice"
    ]
    # from products_old: marketingTexts, names
    try:
        matching_product = old_products[product["ean"]]["synkkaData"]
        if "marketingTexts" in matching_product and len(matching_product["marketingTexts"]) > 0:
            product["marketingTexts"] = matching_product["marketingTexts"]
        if "names" in matching_product:
            product["names"] = matching_product["names"]
    except KeyError:
        pass

    if isinstance(product["price"], dict):
        product["price"] = product["price"]["value"]
    for image in product.get("images", []):
        if image["format"] == "product":
            product["image"] = f'/product_images/{image["savedImage"]}'
            break

    if "categories" in product:
        new_categories = []
        for category in product["categories"]:
            if "dummyCategory" in category and category["dummyCategory"]:
                continue
            c = {}
            c["code"] = category["code"]
            c["name"] = category["name"]
            new_categories.append(c)
        product["categories"] = new_categories

    if "vendorProductCode" in product["vendor"]:
        del product["vendor"]["vendorProductCode"]
    for key in to_delete:
        if key in product:
            del product[key]
    return product


new_products = list(map(map_product, products))
new_products = [p for p in new_products if p is not None]
with open("products_cleaned.json", "w") as f:
    json.dump(new_products, f, indent=2)

# %%
new_products
# Out:
# [{'categories': [{'code': '1021',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Peeled root vegetables and onions'},
#    {'code': '102',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'salaattipoydan-tuotteet',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Products for salad table'},
#    {'code': 'sadonkorjuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Harvest season'},
#    {'code': 'satokausikalenteri-joulukuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': "December's harvest season calendarÂ® "},
#    {'code': 'hevi-tarjoukset',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'December HeVi Deals'}],
#   'ean': '6430021093356',
#   'price': 8.35,
#   'vendor': {'code': '2062', 'name': 'VÃ–RLÃ–N VIHANNES OY'},
#   'id': '0fca1f99-1385-49d1-8053-f59fd542eb14',
#   'names': [{'value': 'VÖRLÖ PEELED BEETROOT 5KG', 'language': 'en'},
#    {'value': 'VÖRLÖ 5KG KUORITTU PUNAJUURI', 'language': 'fi'},
#    {'value': 'VÖRLÖ SKALAD RÖDBETA 5KG', 'language': 'sv'}],
#   'image': '/product_images/img_0270_239aebb015.jpg'},
#  {'categories': [{'code': '1034',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-heinakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® July'}],
#   'ean': '6416124502100',
#   'price': 7.49,
#   'vendor': {'code': '1855', 'name': 'VALMIX OY'},
#   'id': '0f5a0e24-c597-4775-a662-025332bbfdf7',
#   'marketingTexts': [{'value': 'Valmix Zucchini bits is fresh zucchini in coarse blocks.',
#     'language': 'en'},
#    {'value': 'Valmix Zuccinilohko on tuoretta kesäkurpitsaa rouheina lohkoina.',
#     'language': 'fi'},
#    {'value': 'Valmix Zucchini bitar är färsk zucchini i grova block.',
#     'language': 'sv'}],
#   'names': [{'value': 'Valmix Zucchini bits 1kg', 'language': 'en'},
#    {'value': 'Valmix Zuccinilohko 1kg', 'language': 'fi'},
#    {'value': 'Valmix Zucchini bitar 1kg', 'language': 'sv'}],
#   'image': '/product_images/img_0513_7f8a5d9e55.jpg'},
#  {'categories': [{'code': '1012',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Pitted fruits'},
#    {'code': '101', 'dummyCategory': False, 'level': 0, 'name': 'Fruits'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-heinakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® July'}],
#   'ean': '2300340100000',
#   'price': 5.95,
#   'vendor': {'code': '1902', 'name': 'GREEN FOOD IBERICA'},
#   'id': '94ed3684-ea09-4796-a726-74d56634beef',
#   'names': [{'value': 'GRAPES GREEN 4,5 KG BOX ES', 'language': 'en'},
#    {'value': 'RYPÄLE VIHREÄ KIVETÖN 4,5 KG LTK ES', 'language': 'fi'}],
#   'image': '/product_images/img_0086_ce8a75e5b4.jpg'},
#  {'categories': [{'code': '1050',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Boiled potatoes'},
#    {'code': '105', 'dummyCategory': False, 'level': 0, 'name': 'Potatoes'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'salaattipoydan-tuotteet',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Products for salad table'},
#    {'code': 'vappu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Donuts and other May Day treats'},
#    {'code': 'tukustu-jepo',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Wholesaler: Jepuan Peruna Oy'}],
#   'ean': '6416438130303',
#   'price': 12.85,
#   'vendor': {'code': '2115', 'name': 'JEPUAN PERUNA OY'},
#   'id': '9042d0eb-a792-4b2f-9770-dac62f894148',
#   'marketingTexts': [{'value': 'JEPO products are made from 100% Finnish potatoes. With JEPOs cooked spicy potatoproducts you save time and energy. The products are immediately ready for use. JEPO cooked spicy potatoproducts bring all the best delicacies of the harvest season to every kitchen fresh and tasty, with which you get a consistent result all year round. Use as it is or add meat, fish or vegetable protein and liguid of your choice, heat up and this way you can quickly get ready to serve for your customers. Also suitable for cold preparation. The product has the Hyvää Suomesta label, which guarantees that the product is manufactured in Finland and that Finnish raw materials are used.',
#     'language': 'en'},
#    {'value': 'JEPO tuotteet valmistetaan 100%:sti suomalaisesta perunasta. JEPOn kypsillä maustetuilla perunatuotteilla säästät aikaa ja energiaa, tuotteet ovat heti valmiita käytettäväksi. JEPO kypsät maustetut perunatuotteet tuovat kaikki satokauden parhaat herkut jokaiseen keittiöön tuoreena ja maukkaana, joilla saat tasalaatuisen lopputuloksen ympäri vuoden. Käytä sellaisenaan tai lisää esimerkiksi haluamasi liha-, kala- tai kasvisproteiini ja neste, kuumenna ja näin saat nopeasti valmista tarjolle asiakkaillesi. Sopii myös kylmävalmistukseen. Tuotteella on Hyvää Suomesta - merkki, joka takaa tuotteen valmistuksen Suomessa ja suomalaisen raaka-aineen käytön.',
#     'language': 'fi'},
#    {'value': 'JEPO-produkter är tillverkade av 100% finsk potatis. Med JEPO:s mogna kryddade potatisprodukter sparar du tid och energi, produkterna är omedelbart redo att användas. JEPO mogna kryddade potatisprodukter ger alla de bästa delikatesserna under skördesäsongen till varje kök färskt och gott, med vilket du får ett konsekvent resultat året runt. Använd som det är eller lägg till, till exempel kött, fisk eller vegetabiliskt protein och vätska efter eget val, värm och på så sätt kan du snabbt göra dig redo att servera till dina kunder. Också lämplig för kall förberedelse. Produkten har Hyvää Suomesta-märkningen, vilket garanterar att produkten är tillverkad i Finland och att finska råvaror används.',
#     'language': 'sv'}],
#   'names': [{'value': 'JEPO Chipotle Potato 3 kg', 'language': 'en'},
#    {'value': 'JEPO Kypsä Chipotle Peruna 3 kg', 'language': 'fi'},
#    {'value': 'JEPO Kokt Chipotle Potatis 3 kg', 'language': 'sv'}],
#   'image': '/product_images/img_0464_3c982ddbab.jpg'},
#  {'categories': [{'code': '1012',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Pitted fruits'},
#    {'code': '101', 'dummyCategory': False, 'level': 0, 'name': 'Fruits'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'salaattipoydan-tuotteet',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Products for salad table'},
#    {'code': 'satokausikalenteri-heinakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® July'}],
#   'ean': '8437026386030',
#   'price': 3.29,
#   'vendor': {'code': '2091', 'name': 'VEIKKO LAINE OY'},
#   'id': '6bad6f84-9573-4580-bf06-8885743b33fa',
#   'names': [{'value': 'GRAPES GREEN SEEDLESS 500G ES/IT', 'language': 'en'},
#    {'value': 'RYPÄLE VIHREÄ SIEMENETÖN 500G ES/IT', 'language': 'fi'},
#    {'value': 'DRUVOR GRÖNA KÄRNFRIA 500G ES/IT', 'language': 'sv'}],
#   'image': '/product_images/img_0158_08e3ad3e77.jpg'},
#  {'categories': [{'code': '1080',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Sprouts and shoots'},
#    {'code': '108',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Herbs and shoots'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'roomalainen-levypizza',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Roman flat pizza'},
#    {'code': 'napolilainen-pizza',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Neapolitan-style artisan pizza ingredients'},
#    {'code': 'artesaanipizza',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Ingredients for artisan pizza'}],
#   'ean': '6415352200017',
#   'price': 2.8,
#   'vendor': {'code': '1465', 'name': 'KOTIPELLON PUUTARHA OY'},
#   'id': '10b64381-9d0d-4077-bfa7-2b1f3eefb7bc',
#   'names': [{'value': 'MIMIS SALAD TATSOI-ARUGULA-CHARD 70G',
#     'language': 'en'},
#    {'value': 'MIMIS SALAATTI TATSOI-RUCOLA-MANGOLD 70G', 'language': 'fi'},
#    {'value': 'MIMIS SALLAD TATSOI-RUCOLA-MANGOLD 70G', 'language': 'sv'}],
#   'image': '/product_images/img_0141_177f7e9e27.jpeg'},
#  {'categories': [{'code': '1050',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Boiled potatoes'},
#    {'code': '105', 'dummyCategory': False, 'level': 0, 'name': 'Potatoes'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6416438011237',
#   'price': 7.4,
#   'vendor': {'code': '2115', 'name': 'JEPUAN PERUNA OY'},
#   'id': 'a21cc116-8eb5-4a5e-b135-614a4b56c5ea',
#   'marketingTexts': [{'value': 'The JEPO potato products are 100% Finnish potato. With JEPO ripe potato products you save time and energy. The potatoes are immediately ready to use and they do not need to be rinsed. Their quality is consistent all year round. Also suitable to be prepared cold. Small cooking loss. Thanks to the Sous Vide production method, the taste, nutrients and vitamins are well preserved in the product. JEPO Finnish contract potatoes are produced with bio gas in a climate friendly way. The carbon footprint of the product is 27.8 g CO₂-eq / 100g of potatoes produced. The product has the Hyvää Suomesta label, which guarantees that the product is manufactured in Finland and that Finnish raw materials are used.',
#     'language': 'en'},
#    {'value': 'JEPO perunatuotteet valmistetaan 100%:sti suomalaisesta perunasta. JEPO kypsillä perunatuotteilla säästät aikaa ja energiaa. Perunat on heti valmiita käytettäväksi eikä niitä tarvitse huuhtoa. Tasalaatuinen tuote ympäri vuoden. Sopii myös kylmävalmistukseen. Pieni kypsennyshävikki. Sous Vide valmistusmenetelmän ansiosta maku, ravintoaineet ja vitamiinit säilyvät tuotteessa hyvin. JEPOn Suomalainen sopimusviljelty peruna on ilmastoystävällisesti biokaasulla valmistettua. Tuotteen hiilijalanjälki 27,8 g CO₂-ekv./100g tuotettua perunaa. Tuotteella on Hyvää Suomesta - merkki, joka takaa tuotteen valmistuksen Suomessa ja suomalaisen raaka-aineen käytön.',
#     'language': 'fi'},
#    {'value': 'JEPO potatisprodukter är 100% finsk potatis. Med JEPO färska potatisprodukter sparar du både tid och energi. Potatisar är genast färdiga att använda och de behöver inte sköljas. En enhetlig produkt under hela året. Passar också till att lagas kallt. Liten matlagningsgförlust. Tack vare Sous Vide beredningsmetoden bevaras smak, näringsämnen och vitaminer väl i produkten. JEPO finska kontrakspotatis är tillverkad med biogas på ett klimatvänligt sätt.  Produktens koldioxidavtryck är 27,8 g CO₂-eq / 100 g producerad potatis. Produkten har Hyvää Suomesta-märkningen, vilket garanterar att produkten är tillverkad i Finland och att finska råvaror används.',
#     'language': 'sv'}],
#   'names': [{'value': 'JEPO Cooked small potatoes 3kg', 'language': 'en'},
#    {'value': 'JEPO Kypsä pikkuperuna 3kg', 'language': 'fi'},
#    {'value': 'JEPO Kokt småpotatis 3kg', 'language': 'sv'}],
#   'image': '/product_images/img_0408_e77231070d.jpg'},
#  {'categories': [{'code': '1020',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '102',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '2300257000000',
#   'price': 4.13,
#   'vendor': {'code': '3010', 'name': 'BUD HOLLAND B.V.'},
#   'id': '1784797b-2143-45d7-a881-4f29337287f3',
#   'names': [{'value': 'YAM ROOT GHANA', 'language': 'en'},
#    {'value': 'JAMS JUURI GHANA', 'language': 'fi'},
#    {'value': 'JAMSRROT GHANA', 'language': 'sv'}],
#   'image': '/product_images/img_0575_1fbfc8fa75.jpg'},
#  {'categories': [{'code': '2020',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Chicken, broiler and turkey meat'},
#    {'code': '202',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh chicken, broiler and turkey'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'sesonkituotteet-kevat-25',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'The most wonderful flavors of spring'}],
#   'ean': '2378127900000',
#   'price': 14.63,
#   'vendor': {'code': '13', 'name': 'ATRIA SUOMI OY TUORE'},
#   'id': 'ce5509b2-3148-49e2-b83c-7c636e38dfbf',
#   'marketingTexts': [{'value': "A 3 kg package of slightly salted Atria Turkey Fillet Cutlets. Fillet cutlets can be used in many dishes. Unseasoned or salted fillet cutlets are suited for many different kinds of dishes. Everything from delicious and rich sauces to exotic dishes, such as fajitas and tortillas. Cooked and cooled, they are also great in a salad. Animal welfare is supervised throughout Atria's food chain.",
#     'language': 'en'},
#    {'value': '3 kg pakkaus miedosti suolattuja Atria kalkkunan fileeleikkeitä. Fileeleike sopii todella moneen ruokaan. Maustamaton tai suolattu fileeleike soveltuu monenlaisiin erilaisiin ruokiin. Aina herkullisista ja täyteläisistä kastikkeista erilaisiin eksoottisiin ruokiin, kuten fajitaksiin tai tortilloihin. Kypsennyksen jälkeen viilennettynä sopii myös mainiosti salaatin joukkoon. Eläinten hyvinvoinnista huolehditaan valvotusti Atrian koko ruokaketjussa.',
#     'language': 'fi'},
#    {'value': 'Förpackning på 3 kg Atria lättsaltade filéschnitzlar av kalkon. Filéschnitzlar passar för en hel del olika rätter. Naturella eller saltade filéschnitzlar passar för en hel del olika rätter. Från alltid läckra och fylliga såser till olika exotiska rätter såsom fajitas eller tortillor. Efter stekningen passar svalnade schnitzlar även utmärkt i sallader. Djurens välmående ombesörjs under tillsyn i Atrias hela metkedja.',
#     'language': 'sv'}],
#   'names': [{'value': 'Atria Thin Turkey Fillet Lighty Salted ca3kg/ca150g',
#     'language': 'en'},
#    {'value': 'Atria Kalkkunan Fileeleike Miedosti Suolattu n3kg/n150g',
#     'language': 'fi'},
#    {'value': 'Atria Filéschitzel av Kalkon Lätt Saltad ca3kg/ca150g',
#     'language': 'sv'}],
#   'image': '/product_images/img_0392_d3986539aa.jpg'},
#  {'categories': [{'code': '1062',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cultivated fresh mushrooms'},
#    {'code': '106', 'dummyCategory': False, 'level': 0, 'name': 'Mushrooms'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'banneri-honka-holding',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh mushrooms'}],
#   'ean': '6416250002406',
#   'price': 2.53,
#   'vendor': {'code': '2041', 'name': 'MYKORA OY'},
#   'id': 'f10fe300-8867-49a3-aa99-03313e458eea',
#   'names': [{'value': 'CATERING MUSHROOM 350G FI', 'language': 'en'},
#    {'value': 'HERKKUSIENI TUORE 350G/RAS SUOMI', 'language': 'fi'},
#    {'value': 'CATERING CHAMPINJON 350G FI', 'language': 'sv'}],
#   'image': '/product_images/img_0126_6091642333.jfif'},
#  {'categories': [{'code': '1013',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Apples & Pears'},
#    {'code': '101', 'dummyCategory': False, 'level': 0, 'name': 'Fruits'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-elokuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® August'}],
#   'ean': '2050000097966',
#   'lotSizeInfo': '13,0 kg / crt',
#   'price': 26.3,
#   'vendor': {'code': '3092', 'name': 'HARVA INTERNATIONAL B.V.'},
#   'id': '4336c9d1-2aea-4836-b747-1501e4b5894b',
#   'names': [{'value': 'APPLE GOLDEN 13KG FR/IT/PL', 'language': 'en'},
#    {'value': 'OMENA GOLDEN 13KG FR/IT/PL', 'language': 'fi'},
#    {'value': 'ÄPPLE GOLDEN 13KG FR/IT/PL', 'language': 'sv'}],
#   'image': '/product_images/img_0060_7a0238405c.jfif'},
#  {'categories': [{'code': '1031',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut root vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6406510901273',
#   'price': 4.95,
#   'vendor': {'code': '1294', 'name': 'FRESH SERVANT OY AB'},
#   'id': 'deccb62b-4fa2-44fd-a7d6-1357e62812be',
#   'names': [{'value': 'Fresh SK Carrot stick 10mm 1,0kg', 'language': 'en'},
#    {'value': 'Fresh SK Porkkana tikku 10mm 1,0kg', 'language': 'fi'},
#    {'value': 'Fresh SK Morot pinne 10mm 1,0kg', 'language': 'sv'}],
#   'image': '/product_images/img_0496_1bdd6e9135.jpg'},
#  {'categories': [{'code': '2030',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Ground meat'},
#    {'code': '203', 'dummyCategory': False, 'level': 0, 'name': 'Fresh meat'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6409620002588',
#   'price': 24.19,
#   'vendor': {'code': '79', 'name': 'SNELLMAN LIHANJALOSTUS PIETARSAARI'},
#   'id': 'e9ef5a12-de39-460a-aae1-3602669cbe8d',
#   'marketingTexts': [{'value': "Snellman's juicy ground meats are made with respect of the hand cut, fresh raw material. High quality is guaranteed by 100% Finnish meat from our family farms. Another key factor is the use of fresh raw material, which also prevents the meat not to boil in a pan, but to cook nicely",
#     'language': 'en'},
#    {'value': 'Snellmanin mehevät jauhelihat valmistetaan käsinleikatusta lihasta tuoreita raaka-aineita kunnioittaen. Kunnon jauhelihan korkean laadun takaa 100 % suomalainen liha perhetiloiltamme. Toinen tärkeä tekijä on tuoreus, sillä emme käytä jauhelihan valmistuksessa pakastettua lihaa. Näin varmistamme, että Kunnon jauheliha paistuu eikä kiehu pannulla.',
#     'language': 'fi'},
#    {'value': 'Snellmans Riktigt malet kött av nöt är gjort på färskt nötkött som inte varit fryst vid något tillfälle. Köttet kommer från familjegårdar i Finland där djuren utfodras med gmo-fritt foder.',
#     'language': 'sv'}],
#   'names': [{'value': 'Snellman Beef minced meat 17% 2 kg', 'language': 'en'},
#    {'value': 'Snellman Kunnon naudan jauheliha 17% 2 kg', 'language': 'fi'},
#    {'value': 'Snellman Malet kött av nöt 17% 2 kg', 'language': 'sv'}],
#   'image': '/product_images/img_0343_ab253ddbdd.jpg'},
#  {'categories': [{'code': '2020',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Chicken, broiler and turkey meat'},
#    {'code': '202',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh chicken, broiler and turkey'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '2378126700000',
#   'price': 10.33,
#   'vendor': {'code': '13', 'name': 'ATRIA SUOMI OY TUORE'},
#   'id': '388dd7e3-f96f-4319-bdcb-ab9c8ba59859',
#   'marketingTexts': [{'value': 'Atria slightly salted chicken fillet \x96 3.8 kgUnseasoned Atria Chicken Fillets can be used in many chicken dishes. Unseasoned or salted chicken fillets are an excellent main ingredient that can be prepared in a variety of ways. Unseasoned whole fillets are suited for many different kinds of dishes. Cooked and cooled, they are also great in a salad. The antibiotic-free label on the package shows that the animals have not had any antibiotics during their lifetime.',
#     'language': 'en'},
#    {'value': 'Atria kanan filee miedosti suolattuna - 3,8kgMaustamaton Atria kanan filee tilajäljitettävä sopii todella moneen kanaruokaan. Kokille maustamaton tai suolattu kanan filee pääruoka-aineena erinomainen ja sen voikin valmistaa moneen eri muotoon. Maustamaton kokonainen filee soveltuu monenlaisiin erilaisiin ruokiin. Kypsennyksen jälkeen viilennettynä sopii myös mainiosti salaatin joukkoon. Antibioottivapaa-merkintä pakkauksessa kertoo, että eläimet eivät ole tarvinneet ainuttakaan antibioottikuuria elämänsä aikana.',
#     'language': 'fi'},
#    {'value': 'Atria lättsaltad kycklingfilé, 3,8 kg.Atria naturell kycklingfilé passar för en hel del olika kycklingrätter. För en kock är naturell eller saltad kycklingfilé en utmärkt ingrediens i huvudrätter för den kan lagas till många olika rätter. Naturell hel kycklingfilé passar för en hel del olika rätter. Efter stekningen passar svalnade schnitzlar även utmärkt i sallader. Märkningen "antibiotikafri" på förpackningen berättar att djuren inte har behövt en enda antibiotikakur under sitt liv.',
#     'language': 'sv'}],
#   'names': [{'value': 'Atria Chicken Fillet Lightly Salted ca3kg/ca150g',
#     'language': 'en'},
#    {'value': 'Atria Kanan Filee Miedosti Suolattu tilajäljitettävä n3kg/n150g',
#     'language': 'fi'},
#    {'value': 'Atria Kyckling Filé Lätt Saltad ca3kg/ca150g',
#     'language': 'sv'}],
#   'image': '/product_images/img_0421_437632f643.jpg'},
#  {'categories': [{'code': '1031',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut root vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-joulukuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': "December's harvest season calendarÂ® "},
#    {'code': 'hevi-sesongissa',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'In season right now'},
#    {'code': 'satokausikalenteri-tammikuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® January'}],
#   'ean': '6416124789020',
#   'price': 7.99,
#   'vendor': {'code': '1855', 'name': 'VALMIX OY'},
#   'id': 'cdfc76a6-95db-465a-b26e-19b9cd826894',
#   'marketingTexts': [{'value': 'Valmix Carrot bits yellow is a coarse fresh carrot block, size approx. 2 x 3 x 3 cm.',
#     'language': 'en'},
#    {'value': 'Valmix Porkkanalohko särä keltainen on rouhea tuore porkkanalohko, koko noin 2 x 3 x 3 cm.',
#     'language': 'fi'},
#    {'value': 'Valmix Morot i bitar gul är ett grovt färskt morotsblock, storlek ca 2 x 3 x 3 cm.',
#     'language': 'sv'}],
#   'names': [{'value': 'Valmix Carrot bits särä yellow (handcut) 1kg',
#     'language': 'en'},
#    {'value': 'Valmix Porkkanalohko särä keltainen (käsinl.) 1kg',
#     'language': 'fi'},
#    {'value': 'Valmix Morötter i bitar särä gul (handskuren) 1kg',
#     'language': 'sv'}],
#   'image': '/product_images/img_0445_b2cb67aaa3.jpg'},
#  {'categories': [{'code': '1021',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Peeled root vegetables and onions'},
#    {'code': '102',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'salaattipoydan-tuotteet',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Products for salad table'},
#    {'code': 'sadonkorjuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Harvest season'},
#    {'code': 'satokausikalenteri-joulukuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': "December's harvest season calendarÂ® "},
#    {'code': 'satokausikalenteri-helmikuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': "February's harvest season calendarÂ® "}],
#   'ean': '6430021093035',
#   'price': 8.75,
#   'vendor': {'code': '2062', 'name': 'VÃ–RLÃ–N VIHANNES OY'},
#   'id': 'fe8ad42f-146b-471e-8486-3b8d6f4ebebd',
#   'names': [{'value': 'VÖRLÖ 5KG SWEDE PEELED', 'language': 'en'},
#    {'value': 'VÖRLÖ 5KG LANTTU KUORITTU', 'language': 'fi'},
#    {'value': 'VÖRLÖ 5KG KÅLROT SKALAD', 'language': 'sv'}],
#   'image': '/product_images/img_0228_25361a1b73.jpg'},
#  {'categories': [{'code': '1080',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Sprouts and shoots'},
#    {'code': '108',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Herbs and shoots'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'sesonkituotteet-kesa',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Wonderful summer favors'}],
#   'ean': '6430053060098',
#   'price': 19.72,
#   'vendor': {'code': '1465', 'name': 'KOTIPELLON PUUTARHA OY'},
#   'id': '59cf64bf-05e6-4b74-a782-210808f9a596',
#   'names': [{'value': 'MIMIS CRESS MIX BOX', 'language': 'en'},
#    {'value': 'MIMIS VERSOBOXI LTK', 'language': 'fi'},
#    {'value': 'MIMIS GRODDMIX ASK', 'language': 'sv'}],
#   'image': '/product_images/img_0178_0d34c34df0.PNG'},
#  {'categories': [{'code': '2032',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Pork and piglet'},
#    {'code': '203', 'dummyCategory': False, 'level': 0, 'name': 'Fresh meat'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '2378559000000',
#   'price': 12.25,
#   'vendor': {'code': '13', 'name': 'ATRIA SUOMI OY TUORE'},
#   'id': '70511bb5-5027-4e3d-b6aa-891f9bd75753',
#   'marketingTexts': [{'value': 'This ready-made slice from pork feels at home in different kinds of cooking. Atria\x92s Cooked Pork Slices are made from Finnish meat. The Pork Slices are available in 2 kg packs.',
#     'language': 'en'},
#    {'value': 'Valmiiksi kypsennetty possun suikale sopii monenlaiseen ruuanvalmistukseen. Atria kypsä possunsuikale on valmistettu suomalaisesta lihasta. Possunsuikaleet ovat saatavilla 2 kg pakkauksissa.',
#     'language': 'fi'},
#    {'value': 'Denna färdigt tillagade fläskstrimla kan användas till många olika sorters matlagning. Atrias färdigtillagade fläskstrimla är gjord på finländskt kött. Fläskstrimlorna finns tillgängliga i förpackningar om 2 kg.',
#     'language': 'sv'}],
#   'names': [{'value': 'Atria Cooked Pork Stripes ca2kg', 'language': 'en'},
#    {'value': 'Atria Kypsä Possun 0 Suikale n2kg', 'language': 'fi'},
#    {'value': 'Atria Kokt Gris 0 Strimlor ca2kg', 'language': 'sv'}],
#   'image': '/product_images/img_0091_ba2c3e62df.jpg'},
#  {'categories': [{'code': '1074',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Salads'},
#    {'code': '107', 'dummyCategory': False, 'level': 0, 'name': 'Vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'sesonkituotteet-kevat-25',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'The most wonderful flavors of spring'},
#    {'code': 'satokausikalenteri-kesakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® June'}],
#   'ean': '6415352230137',
#   'price': 13.15,
#   'vendor': {'code': '1623', 'name': 'VAANELAN PUUTARHA OY'},
#   'id': '09d0de4b-fde3-4fff-bf45-4625dfa4fbc1',
#   'names': [{'value': 'ICE LETTUCE LOOSE LEAVES 1ST CLASS 2KG',
#     'language': 'en'},
#    {'value': 'JÄÄSALAATTI IRTOLEHTI 1LK SUOMI 2KG', 'language': 'fi'},
#    {'value': 'ISSALLAD LÖST BLAD1:A KLASS 2KG', 'language': 'sv'}],
#   'image': '/product_images/img_0149_b4add3f345.jpg'},
#  {'categories': [{'code': '2011',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Processed fish'},
#    {'code': '201', 'dummyCategory': False, 'level': 0, 'name': 'Fresh fish'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'joulu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Christmas products'}],
#   'ean': '6411440060358',
#   'price': 29.54,
#   'vendor': {'code': '1090', 'name': 'SUOMEN SILLIKONTTORI OY'},
#   'id': 'ee1af129-0b9a-4910-86b7-ad76a5226b1f',
#   'names': [{'value': 'Sillikonttori Tar Baltic Herring 3kg/1,5kg MSC',
#     'language': 'en'},
#    {'value': 'Sillikonttori Tervasilakka 3kg/1,5kg MSC', 'language': 'fi'},
#    {'value': 'Sillikonttori Tjärströmming 3kg/1,5kg MSC', 'language': 'sv'}],
#   'image': '/product_images/img_0349_e232cfa024.jpg'},
#  {'categories': [{'code': '1070',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cabbages'},
#    {'code': '107', 'dummyCategory': False, 'level': 0, 'name': 'Vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'vaasan-vihannes',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Vaasan Vihannes '}],
#   'ean': '2300236500000',
#   'price': 6.08,
#   'vendor': {'code': '2150', 'name': 'OY VAASAN VIHANNES - VASA GRÃ–NSAKER'},
#   'id': 'e534d190-1a8b-43ff-a209-79c06d5ec93e',
#   'names': [{'value': 'CAULIFLOWER ROMANESCO FINLAND', 'language': 'en'},
#    {'value': 'KUKKAKAALI ROMANESCO SUOMI', 'language': 'fi'},
#    {'value': 'BLOMKÅL ROMANESCO FINLAND', 'language': 'sv'}],
#   'image': '/product_images/img_0058_1ceb6295c5.jpg'},
#  {'categories': [{'code': '2011',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Processed fish'},
#    {'code': '201', 'dummyCategory': False, 'level': 0, 'name': 'Fresh fish'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'joulu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Christmas products'}],
#   'ean': '6411440021236',
#   'price': 33.92,
#   'vendor': {'code': '1090', 'name': 'SUOMEN SILLIKONTTORI OY'},
#   'id': 'abcb50d2-19fb-40cf-8b34-0f34329dc376',
#   'marketingTexts': [{'value': 'Sillifileen paloja valkosipulikastikkeessa',
#     'language': 'fi'},
#    {'value': 'Sillfiléer i vitlökssås', 'language': 'sv'}],
#   'names': [{'value': 'Suomen Sillikonttori Garlic Herring 3kg/1,5kg MSC',
#     'language': 'en'},
#    {'value': 'Suomen Sillikonttori Valkosipulisilli 3kg/1,5kg MSC',
#     'language': 'fi'},
#    {'value': 'Suomen Sillikonttori Vitlöksill  3kg/1,5kg MSC',
#     'language': 'sv'}],
#   'image': '/product_images/img_0239_3251655d3a.jpg'},
#  {'categories': [{'code': '2010',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cured and cold smoked fish'},
#    {'code': '201', 'dummyCategory': False, 'level': 0, 'name': 'Fresh fish'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '2385257100000',
#   'price': 28.19,
#   'vendor': {'code': '1950', 'name': 'KALANEUVOS OY TUORE'},
#   'id': '0db10fec-0d6b-4cb1-b779-75c9194ff266',
#   'marketingTexts': [{'value': 'Gravad rainbow trout fillet is the number one treat at banquets – it crowns every fish buffet at Christmas celebrations or other festive occasions. It is also an unbeatable and popular treat on bread.\n\nKalaneuvos rainbow trout is sustainably farmed, either in the Finnish Archipelago Sea and Åland or in Sweden. It is safe and ecological locally produced food. Kalaneuvos gravad rainbow trout fillet slices are always prepared from fresh, not frozen, fish.',
#     'language': 'en'},
#    {'value': 'Graavikirjolohifilee on juhlapöytien ehdoton maun tuoja, on sitten kyse joulun tai muiden juhlapäivien kalapöydästä. Voileivän päällä se on myös lyömätön ja suosittu herkku.\n\nKalaneuvoksen kirjolohet on kasvatettu vastuullisesti joko Suomen Saaristomerellä ja Ahvenanmaalla tai Ruotsissa. Se on turvallista ja ekologista lähiruokaa. Kalaneuvoksen graavatut kirjolohifileesiivut valmistetaan aina tuoreesta kalasta, ei pakasteesta.',
#     'language': 'fi'},
#    {'value': 'Gravad regnbågslaxfilé är en obestridlig smakhöjdpunkt på festbordet, såväl på julbordet som andra festbord. Som smörgåspålägg är den även en oslagbar och populär delikatess.\n\nKalaneuvos regnbågslaxar är hållbart odlade antingen i Skärgårdshavet i Finland och på Åland eller i Sverige. Lax är trygg och ekologisk närmat. Kalaneuvos gravade regnbågslaxfilé i skivor tillverkas alltid av färsk och inte fryst fisk.',
#     'language': 'sv'}],
#   'names': [{'value': 'Kalaneuvos Lightly salted sliced trout fillet ca750g vac',
#     'language': 'en'},
#    {'value': 'Kalaneuvos Graavi kirjolohifilee siivu n750g vak',
#     'language': 'fi'},
#    {'value': 'Kalaneuvos Gravad regnbågslax filé skiva ca750g vak',
#     'language': 'sv'}],
#   'image': '/product_images/img_0132_ab688bd6a3.jpg'},
#  {'categories': [{'code': '2014',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Wild fish'},
#    {'code': '201', 'dummyCategory': False, 'level': 0, 'name': 'Fresh fish'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'tammikuu-tuoreet-tuontikalat',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh imported fish'}],
#   'ean': '2300642900000',
#   'price': 29.76,
#   'vendor': {'code': '1663', 'name': 'KALAMAKASIINI OY'},
#   'id': '5a740516-1a8d-47e9-9263-04cfd3b9aff2',
#   'names': [{'value': 'Flounderfillet fresh 5kg MSC', 'language': 'en'},
#    {'value': 'Punakampelafile tuore 5kg MSC', 'language': 'fi'},
#    {'value': 'Rödspättafile färska 5kg MSC', 'language': 'sv'}],
#   'image': '/product_images/img_0329_b945e163f3.jpg'},
#  {'categories': [{'code': '1034',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'burgerit',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Everything for tasty burgers'},
#    {'code': 'hot-dog',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Versatile hot dog'}],
#   'ean': '6406510952411',
#   'price': 17.39,
#   'vendor': {'code': '1294', 'name': 'FRESH SERVANT OY AB'},
#   'id': '137e416f-ff50-458f-9720-6fef445c21ed',
#   'names': [{'value': 'Fresh SalaattiMestari Fresh jalapeno slice pickled 1,0kg GN1/6',
#     'language': 'en'},
#    {'value': 'Fresh SalaattiMestari Tuore jalapenoviipale pikkelöity 1,0kg GN1/6',
#     'language': 'fi'},
#    {'value': 'Fresh SalaattiMestari Färsk jalapeno skiva picklad 1,0kg GN1/6',
#     'language': 'sv'}],
#   'image': '/product_images/img_0302_58ce9da11d.jpg'},
#  {'categories': [{'code': '1020',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '102',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-helmikuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': "February's harvest season calendarÂ® "},
#    {'code': 'satokausikalenteri-maaliskuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® March'},
#    {'code': 'satokausikalenteri-huhtikuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® April'}],
#   'ean': '2300106200000',
#   'price': 5.9,
#   'vendor': {'code': '3010', 'name': 'BUD HOLLAND B.V.'},
#   'id': '30bc22b6-eb3d-43ed-8b10-c77801b7872c',
#   'names': [{'value': 'SWEET POTATO PURPLE USA', 'language': 'en'},
#    {'value': 'BATAATTI LILA USA', 'language': 'fi'},
#    {'value': 'SÖTPOTATIS LILA USA', 'language': 'sv'}],
#   'image': '/product_images/img_0007_a7a432d45a.jfif'},
#  {'categories': [{'code': '1030',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-toukokuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® May'},
#    {'code': 'satokausikalenteri-kesakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® June'}],
#   'ean': '6416124617002',
#   'price': 8.3,
#   'vendor': {'code': '1855', 'name': 'VALMIX OY'},
#   'id': '1b5a960b-9d62-45e3-a635-885379447097',
#   'marketingTexts': [{'value': 'Valmix honey dew melon cubes 20mm is a juicy, easy-to-use honeydew melon cube, size approx. 2 x 2 x 2 cm.',
#     'language': 'en'},
#    {'value': 'Valmix Hunajamelonikuutio 20mm on mehukas helppokäyttöinen hunajamelonikuutio, koko noin 2 x 2 x 2 cm.',
#     'language': 'fi'},
#    {'value': 'Valmix honungsmelon tärnad 20mm är en saftig, lättanvänd honungsmelonkub, storlek ca 2 x 2 x 2 cm.',
#     'language': 'sv'}],
#   'names': [{'value': 'Valmix honey dew melon cubes 20mm 1kg',
#     'language': 'en'},
#    {'value': 'Valmix hunajamelonikuutio 20mm 1kg', 'language': 'fi'},
#    {'value': 'Valmix honungsmelon tärnad 20mm 1kg', 'language': 'sv'}],
#   'image': '/product_images/img_0405_00723e099f.jpg'},
#  {'categories': [{'code': '1071',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cucumbers, Zucchini & Pumpkins'},
#    {'code': '107', 'dummyCategory': False, 'level': 0, 'name': 'Vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-lokakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® October'}],
#   'ean': '2300123300000',
#   'price': 1.99,
#   'vendor': {'code': '1963', 'name': 'VELJEKSET KITOLA OY'},
#   'id': '9e496a4f-7dcd-47b4-8956-0dc168789434',
#   'names': [{'value': 'KURPITSA SUOMI', 'language': 'en'},
#    {'value': 'SPAGETTIKURPITSA SUOMI', 'language': 'fi'}],
#   'image': '/product_images/img_0436_287970249e.jpg'},
#  {'categories': [{'code': '1034',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6420614594544',
#   'price': 18.69,
#   'vendor': {'code': '2159', 'name': 'SALICO OY'},
#   'id': '48987521-9bbc-4917-aecb-0175a3f6fd9b',
#   'marketingTexts': [{'value': 'Quick and easy with pre-processed SallaCarte products. A slice of porcini mushroom is excellent for dishes and salads.',
#     'language': 'en'},
#    {'value': 'Nopeaa ja helppoa esikäsitellyillä SallaCarte- tuotteilla. Herkkusieniviipale soveltuu erinomaisesti ruokiin ja salaatteihin.',
#     'language': 'fi'},
#    {'value': 'Snabbt och enkelt med förbearbetade SallaCarte-produkter. En skiva porcini-svamp passar utmärkt till rätter och sallader.',
#     'language': 'sv'}],
#   'names': [{'value': 'SallaCarte Champignon slice 1,5 kg 1/2 GN',
#     'language': 'en'},
#    {'value': 'SallaCarte Herkkusieniviipale 1,5 kg 1/2 GN', 'language': 'fi'},
#    {'value': 'SallaCarte Champinjonskiva 1,5 kg 1/2 GN', 'language': 'sv'}],
#   'image': '/product_images/img_0262_134e30dbc3.jpg'},
#  {'categories': [{'code': '1034',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-heinakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® July'}],
#   'ean': '6430040356616',
#   'price': 5.45,
#   'vendor': {'code': '2019', 'name': 'BAMA FRESH CUTS OY'},
#   'id': 'aff84b34-b745-4bbc-a8f3-9d2a823627fc',
#   'names': [{'value': 'Bama Zucchini strip 5mm 1kg', 'language': 'en'},
#    {'value': 'Bama Kesäkurpitsasuikale 5mm 1kg', 'language': 'fi'},
#    {'value': 'Bama Zucchinistrimla 5mm 1kg', 'language': 'sv'}],
#   'image': '/product_images/img_0381_28d35a5a2e.jpg'},
#  {'categories': [{'code': '1034',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6420614595527',
#   'price': 17.59,
#   'vendor': {'code': '2159', 'name': 'SALICO OY'},
#   'id': 'be34ccc4-77ae-4c22-85ca-90ded56a194f',
#   'marketingTexts': [{'value': 'Ratatouille is a traditional dish from Provence, France. It is a hot or cold vegetable stew, served as a main course with rice, potatoes or bread, or as a side dish. SallaCarte Ratatouille contains paprika, zucchini and red onion. If you want, you can add more vegetables to the rataouille according to your preference.',
#     'language': 'en'},
#    {'value': 'Ratatouille on perinteinen ruokalaji Ranskan Provencesta. Se on kuumana tai kylmänä nautittava vihannesmuhennos, joka tarjotaan pääruokana riisin, perunoiden tai leivän kera tai lisukkeena. SallaCarte Ratatouille sisältää paprikaa, kesäkurpitsaa ja punasipulia. Halutessaan rataouilleen voi lisätä kasviksia lisää mieltymyksensä mukaan.',
#     'language': 'fi'},
#    {'value': 'Ratatouille är en traditionell maträtt från Provence, Frankrike. Det är en varm eller kall grönsaksgryta, serverad som huvudrätt med ris, potatis eller bröd, eller som tillbehör. SallaCarte Ratatouille innehåller paprika, zucchini och rödlök. Om du vill kan du lägga till fler grönsaker till rataouillen enligt dina önskemål.',
#     'language': 'sv'}],
#   'names': [{'value': 'SallaCarte Ratatouille à la carte 2 kg',
#     'language': 'en'},
#    {'value': 'SallaCarte Ratatouille à la carte 2 kg', 'language': 'fi'},
#    {'value': 'SallaCarte Ratatouille à la carte 2 kg', 'language': 'sv'}],
#   'image': '/product_images/img_0243_795ff239d3.jpg'},
#  {'categories': [{'code': '2030',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Ground meat'},
#    {'code': '203', 'dummyCategory': False, 'level': 0, 'name': 'Fresh meat'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6407840042810',
#   'lotSizeInfo': '3 pcs / crt',
#   'price': 29.85,
#   'vendor': {'code': '13', 'name': 'ATRIA SUOMI OY TUORE'},
#   'id': 'ff7183f5-4dc6-4f56-a927-03a1e5b8eac2',
#   'marketingTexts': [{'value': "Atria's Parempi Nauta Jauheliha is a perfect choice for anyone looking for ingredients that are low on fat, but big on taste. The mince is made of carefully selected cuts of beef, and it contains only 10% fat. Low-fat mince is a perfect choice when you want focus on the taste of refreshing spices and healthy vegetables. Try this mince in sauces and soups. The tasty low-fat mince is perfect for pizzas since a lighter meat topping is a good companion for fatty cheese.",
#     'language': 'en'},
#    {'value': 'Atrian Parempi Nauta Jauheliha sopii ihmisille, jotka haluavat syödä vähärasvaisesti, mutta maukkaasti. Jauhelihan alhainen 10 % rasvaosuus muodostuu tarkoin valituista paloista nautaa. Vähärasvainen liha soveltuu hyvin ruokiin, joissa halutaan korostaa mausteiden raikkautta ja kasvisten terveellisyyttä. Kokeile jauhelihaa esimerkiksi kastikkeisiin ja keittoihin. Erinomainen käyttökohde vähärasvaiselle jauhelihalle on pizza, jossa rasvaisen juuston rinnalle sopii kevyempi lihatäyte.',
#     'language': 'fi'},
#    {'value': 'Atria Bättre Nötköttfärs passar den som vill äta en smakrik kost med låg fetthalt. Köttfärsen har en låg fetthalt på 10 % och består av noga utvalt nötkött. Kött med låg fetthalt lämpar sig väl för maträtter där man vill betona fräscha kryddor och hälsosamma grönsaker. Prova köttfärsen i exempelvis såser och soppor. Köttfärs med låg fetthalt är en utmärkt fyllning för exempelvis pizzor, där en lättare köttfyllning gör sig väl med fetare ost.',
#     'language': 'sv'}],
#   'names': [{'value': 'Atria Better Minced Meat of Beef 10% 3x700g',
#     'language': 'en'},
#    {'value': 'Atria Parempi Nauta Jauheliha 10% 3x700g', 'language': 'fi'},
#    {'value': 'Atria Bättre Malet Kött av Nöt 10% 3x700g', 'language': 'sv'}],
#   'image': '/product_images/img_0265_90c17560bb.jpg'},
#  {'categories': [{'code': '1076',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Tomatoes'},
#    {'code': '107', 'dummyCategory': False, 'level': 0, 'name': 'Vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'kebab-tuotteita',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Kebab products'}],
#   'ean': '2300110100000',
#   'price': 2.2,
#   'vendor': {'code': '1804', 'name': 'STAAY FOOD GROOP B.V.'},
#   'id': '98044932-31a8-4aa9-8bff-2b53c5503023',
#   'names': [{'value': 'TOMATO NL/BE/ES 1.CL', 'language': 'en'},
#    {'value': 'TOMAATTI NL/BE/ES 1.LK', 'language': 'fi'}],
#   'image': '/product_images/img_0665_92697c40ab.jpg'},
#  {'categories': [{'code': '1080',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Sprouts and shoots'},
#    {'code': '108',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Herbs and shoots'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6415350014654',
#   'price': 4.28,
#   'vendor': {'code': '1465', 'name': 'KOTIPELLON PUUTARHA OY'},
#   'id': '7ef6ecb4-fe6e-482a-b339-7895e306161d',
#   'names': [{'value': 'MIMIS SANGO CRESS 40G/BOX', 'language': 'en'},
#    {'value': 'MIMIS SANGO SKOTT 40G/ASK', 'language': 'es'},
#    {'value': 'MIMIS SANGO VERSO 40G/RASIA', 'language': 'fi'}],
#   'image': '/product_images/img_0520_68f3fd11dc.jpg'},
#  {'categories': [{'code': '1015',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Other fruits'},
#    {'code': '101', 'dummyCategory': False, 'level': 0, 'name': 'Fruits'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'salaattipoydan-tuotteet',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Products for salad table'},
#    {'code': 'pikatukkujen-viikon-tarjoukset-vk44',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cash & carry offers of the week'},
#    {'code': 'satokausikalenteri-toukokuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® May'},
# ...
#  {'categories': [{'code': '2035',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Veal and beef'},
#    {'code': '203', 'dummyCategory': False, 'level': 0, 'name': 'Fresh meat'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '2381908900000',
#   'price': 16.87,
#   'vendor': {'code': '1205', 'name': 'KAIVON LIHA KAUNISMAA OY TUORE'},
#   'id': 'fdbc6905-1dea-4258-b24d-c1c8a790f008',
#   'names': [{'value': 'Well Beef Beef Chuck roll n 3 kg', 'language': 'en'},
#    {'value': 'Well Beef Naudan Chuck roll n 3 kg', 'language': 'fi'},
#    {'value': 'Well Beef Nöt Chuck roll ca 3 kg', 'language': 'sv'}],
#   'image': '/product_images/img_0298_f4bc2a850c.jpg'},
#  {'categories': [{'code': '1072',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Bell peppers'},
#    {'code': '107', 'dummyCategory': False, 'level': 0, 'name': 'Vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'luomuhevit',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Organic heavy goods'}],
#   'ean': '2300104000000',
#   'price': 7.15,
#   'tags': ['promoted'],
#   'vendor': {'code': '2091', 'name': 'VEIKKO LAINE OY'},
#   'id': '413fc5f4-60a2-46bc-bb9d-21ddde1586c4',
#   'names': [{'value': 'ORGANIC CAPSICUM RED NETHERLANDS', 'language': 'en'},
#    {'value': 'LUOMU PAPRIKA PUNAINEN HOLLANTI', 'language': 'fi'},
#    {'value': 'EKOLOGISK RÖD PAPRIKA NEDERLÄNDERNA', 'language': 'sv'}],
#   'image': '/product_images/img_0646_649154c850.jpg'},
#  {'categories': [{'code': '1020',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '102',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'salaattipoydan-tuotteet',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Products for salad table'},
#    {'code': 'sadonkorjuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Harvest season'},
#    {'code': 'satokausikalenteri-joulukuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': "December's harvest season calendarÂ® "},
#    {'code': 'hevi-sesongissa',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'In season right now'},
#    {'code': 'satokausikalenteri-elokuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® August'},
#    {'code': 'satokausikalenteri-syyskuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® september'},
#    {'code': 'satokausikalenteri-marraskuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® November'}],
#   'ean': '2300257800000',
#   'price': 2.47,
#   'vendor': {'code': '2150', 'name': 'OY VAASAN VIHANNES - VASA GRÃ–NSAKER'},
#   'id': '553af9e7-7da6-4851-b6d4-b943df27a72e',
#   'names': [{'value': 'BEETROOT YELLOW WASHED FINLAND', 'language': 'en'},
#    {'value': 'KELTAJUURI PESTY SUOMI', 'language': 'fi'},
#    {'value': 'GULBETA TVÄTTAD FINLAND', 'language': 'sv'}],
#   'image': '/product_images/img_0611_53381814b3.jpg'},
#  {'categories': [{'code': '1034',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-joulukuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': "December's harvest season calendarÂ® "},
#    {'code': 'satokausikalenteri-lokakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® October'}],
#   'ean': '6416124789785',
#   'price': 6.99,
#   'vendor': {'code': '1855', 'name': 'VALMIX OY'},
#   'id': 'c5d14152-437c-4266-b7cf-203366f82ae2',
#   'marketingTexts': [{'value': 'Valmix Butternut squash cube is fresh pumpkin in cubes, size approx. 1,5 x 1,5 x 1,5 cm.',
#     'language': 'en'},
#    {'value': 'Valmix Myskikurpitsakuutio on tuoretta myskikurpitsaa kuutioina, koko noin 1,5 x 1,5 x 1,5 cm.',
#     'language': 'fi'},
#    {'value': 'Valmix Butternutpumpa tärnad är färsk pumpa i kuber, storlek ca 1,5 x 1,5 x 1,5 cm.',
#     'language': 'sv'}],
#   'names': [{'value': 'Valmix Butternut squash cube 15mm 1kg',
#     'language': 'en'},
#    {'value': 'Valmix Myskikurpitsakuutio 15mm 1kg', 'language': 'fi'},
#    {'value': 'Valmix Butternutpumpa tärnad 15mm 1kg', 'language': 'sv'}],
#   'image': '/product_images/img_0460_3792995582.jpg'},
#  {'categories': [{'code': '1050',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Boiled potatoes'},
#    {'code': '105', 'dummyCategory': False, 'level': 0, 'name': 'Potatoes'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'black-week',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Black Week tarjoukset'}],
#   'ean': '6430012991036',
#   'price': 4.65,
#   'vendor': {'code': '609', 'name': 'POTWELL OY'},
#   'id': '14740cce-5c78-45ef-ace4-351185b4534a',
#   'names': [{'value': 'Maatilan Precooked potato wedges skin on 2,5 kg',
#     'language': 'en'},
#    {'value': 'Maatilan Keitetty kuorellinen lohkoperuna 2,5 kg',
#     'language': 'fi'},
#    {'value': 'Maatilan Förkokt klyftpotais med skal 2,5 kg',
#     'language': 'sv'}],
#   'image': '/product_images/img_0348_a161d199dc.png'},
#  {'categories': [{'code': '1040',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh berries'},
#    {'code': '104', 'dummyCategory': False, 'level': 0, 'name': 'Berries'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'sesonkituotteet-kevat',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Novelties for spring'},
#    {'code': 'jalkiruoka-kevat',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Versatile desserts'},
#    {'code': 'jalkiruoka',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Dessert crowns the meal'},
#    {'code': 'satokausikalenteri-heinakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® July'}],
#   'ean': '6410705063868',
#   'price': 9.28,
#   'vendor': {'code': '3092', 'name': 'HARVA INTERNATIONAL B.V.'},
#   'id': '2053691d-1a7a-429d-a7f7-51c94762e929',
#   'names': [{'value': 'STRAWBERRIES 500G NL/BE', 'language': 'en'},
#    {'value': 'MANSIKKARASIA 500G NL/BE', 'language': 'fi'},
#    {'value': 'JORDGUBB 500G NL/BE', 'language': 'sv'}],
#   'image': '/product_images/img_0110_0c4a483076.jpg'},
#  {'categories': [{'code': '2010',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cured and cold smoked fish'},
#    {'code': '201', 'dummyCategory': False, 'level': 0, 'name': 'Fresh fish'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'joulu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Christmas products'}],
#   'ean': '2371041000000',
#   'price': 27.19,
#   'vendor': {'code': '1974', 'name': 'KALAVAPRIIKKI OY JALOSTE'},
#   'id': '66e3d13e-3f3a-4c0a-ae34-b91e71a7549d',
#   'marketingTexts': [{'value': 'We in Kalaonni prepare domestic lox food classics with real alder smoke leisurely, so that they have just the right amount of smoke and salt in the flavor. The products only include fresh and clean ingredients - you can taste it. All our lox products are prepared locally in Kuopio. We also favor domestic fish as the ingredient, whose origin is well known',
#     'language': 'en'},
#    {'value': 'Kalaonnilla valmistuu kiireettä aidolla leppäsavulla kylmäkypsytettyjä kotimaisia kalaruokaklassikkoja, joissa on savua ja suolaa juuri sopivassa suhteessa. Lisäksi tuotteissa maistuvat vain tuoreet ja puhtaat raaka-aineet. Kaikki kylmäsavutuotteemme valmistetaan kotoisasti Kuopiossa. Myös raaka-aineena suosimme kotimaista kalaa, jonka alkuperän tunnemme.',
#     'language': 'fi'},
#    {'value': 'Vi på Kalaonni tillagar våra inhemska laxklassiker i lugn och ro med äkta alspån, så att de smakar lagom mycket rök och salt. Våra produkter innehåller endast färska ingredienser och det märks på smaken. Alla våra kallrökta fiskprodukter tillverkas lokalt i Kuopio. Vi föredrar inhemsk och ansvarsfullt odlad fisk, vars ursprung vi känner till.',
#     'language': 'sv'}],
#   'names': [{'value': 'Kalaonni Cold Smoked rainbow trout sliced',
#     'language': 'en'},
#    {'value': 'Kalaonni Kylmäsavu Kirjolohifilee siivutettu\n',
#     'language': 'fi'},
#    {'value': 'Kalaonni Kaltrökt regnbåglax skivad', 'language': 'sv'}],
#   'image': '/product_images/img_0097_d52f06bcc9.jpg'},
#  {'categories': [{'code': '2014',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Wild fish'},
#    {'code': '201', 'dummyCategory': False, 'level': 0, 'name': 'Fresh fish'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '2300635300000',
#   'price': 24.95,
#   'vendor': {'code': '10795', 'name': 'KALAVAPRIIKKI OY TUORE'},
#   'id': '9672a4c2-97ff-470c-9183-a8290aa8bed6',
#   'marketingTexts': [{'value': 'The fresh fish products of Kalaonni are meals that only require cooking: once taken out of the package, you can place them directly on the pan or into the oven or a grill. All fish have been cut as fine fillets and the fishbones have been removed as carefully as possible. All our fresh fish products are prepared locally in Kuopio. We also favor responsible fish farming, whose origin is well known.',
#     'language': 'en'},
#    {'value': 'Kalaonnin tuorekalatuotteet ovat kypsennystä vaille valmista evästä, jotka voi nostaa suoraan paketista pannulle, uuniin tai grilliin kypsymään. Kaikki tuorekalat on leikattu fiiniksi fileiksi, joista on poistettu mahdollisimman tarkasti ruodot. Kaikki tuorekalatuotteemme valmistetaan kotoisasti Kuopiossa. Myös raaka-aineena suosimme vastuullisesti kasvatettua kalaa, jonka alkuperän tunnemme.',
#     'language': 'fi'},
#    {'value': 'De färska och lättlagade fiskprodukterna från Kalaonni är redo att tillagas direkt från sin förpackning i stekpannan, ugnen eller på grillen. Alla våra färska fiskprodukter är omsorgsfullt filerade och fiskbenen har avlägsnats så noggrant som möjligt. Alla våra färska fiskprodukter tillverkas lokalt i Kuopio. Vi föredrar ansvarsfullt odlad fisk, vars ursprung vi känner till.',
#     'language': 'sv'}],
#   'names': [{'value': 'Kalavapriikki Salmon fillet piece ca. 180 g, ASC',
#     'language': 'en'},
#    {'value': 'Kalavapriikki Lohifilee annospala n. 180 g, ASC',
#     'language': 'fi'},
#    {'value': 'Kalavapriikki Laxfile bit ca 180 g, ASC', 'language': 'sv'}],
#   'image': '/product_images/img_0198_6de7ae9ac1.jpg'},
#  {'categories': [{'code': '1031',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut root vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6420614592083',
#   'price': 4.5,
#   'vendor': {'code': '2159', 'name': 'SALICO OY'},
#   'id': '51c54bdc-a209-489c-9387-e3c015367fa0',
#   'marketingTexts': [{'value': 'SallaCarte Coarse carrot grater can easily be a fresh addition to food. Grated carrots are also great for salads and warm dishes.',
#     'language': 'en'},
#    {'value': 'SallaCarte Porkkanaraaste karkeasta saa helposti raikkaan lisäkkeen ruoalle. Porkkanaraaste sopii loistavasti myös salaatteihin ja lämpimiin ruokiin. Laajassa porkkanavalikoimissamme ovat lisäksi SallaCarte Porkkanaraaste ohut, SallaCarte Porkkanalantti, SallaCarte Porkkanakuutio 20 mm, SallaCarte Porkkanatikku ja SallaCarte Porkkanapölkky.',
#     'language': 'fi'},
#    {'value': 'SallaCarte Grovt morotsrivjärn kan lätt vara ett fräscht tillskott till maten. Rivna morötter passar även bra till sallader och varma rätter.',
#     'language': 'sv'}],
#   'names': [{'value': 'SallaCarte Carrot coarse grated 1 kg',
#     'language': 'en'},
#    {'value': 'SallaCarte Porkkanaraaste karkea 1 kg', 'language': 'fi'},
#    {'value': 'SallaCarte Morot råkost 1 kg', 'language': 'sv'}],
#   'image': '/product_images/img_0340_c9de375752.jpg'},
#  {'categories': [{'code': '2035',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Veal and beef'},
#    {'code': '203', 'dummyCategory': False, 'level': 0, 'name': 'Fresh meat'},
#    {'code': '20',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fresh meat and fish'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '2356912800000',
#   'price': 21.29,
#   'vendor': {'code': '937', 'name': 'LIHATUKKU HARRI TAMMINEN OY'},
#   'id': 'd62ea5b3-949d-44e7-8fa4-febf46776123',
#   'names': [{'value': 'Tamminen beef brisket boneless ca3,5kg',
#     'language': 'en'},
#    {'value': 'Tamminen rotu naudan luuton rinta n3,5kg', 'language': 'fi'},
#    {'value': 'Tamminen rasboskap nöt bringa utan ben ca3,5kg',
#     'language': 'sv'}],
#   'image': '/product_images/img_0331_aca113d4cd.jpg'},
#  {'categories': [{'code': '1020',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '102',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Root vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'},
#    {'code': 'satokausikalenteri-helmikuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': "February's harvest season calendarÂ® "},
#    {'code': 'satokausikalenteri-lokakuu',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'SatokausikalenteriÂ® October'}],
#   'ean': '2300253600000',
#   'price': 4.52,
#   'vendor': {'code': '3010', 'name': 'BUD HOLLAND B.V.'},
#   'id': '700f06c2-1e08-416a-8bb2-91d40d8e42b5',
#   'names': [{'value': 'PARSLEY ROOT NL/GR', 'language': 'en'},
#    {'value': 'JUURIPERSILJA NL/GR', 'language': 'fi'},
#    {'value': 'PERSILJEROT NL/GR', 'language': 'sv'}],
#   'image': '/product_images/img_0591_28adb5207d.jpg'},
#  {'categories': [{'code': '1031',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut root vegetables'},
#    {'code': '103',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Cut fruits and vegetables'},
#    {'code': '10',
#     'dummyCategory': False,
#     'level': 0,
#     'name': 'Fruits and Vegetables'},
#    {'code': '0', 'dummyCategory': False, 'level': 0, 'name': 'Front page'}],
#   'ean': '6416124790965',
#   'price': 13.22,
#   'vendor': {'code': '1855', 'name': 'VALMIX OY'},
#   'id': 'f4878ae1-cff1-4f35-8a6a-260bffd88a08',
#   'marketingTexts': [{'value': 'Valmix Carrot dip is a fresh, approx. 10 cm long stick. Great as a snack or supplement, for example.',
#     'language': 'en'},
#    {'value': 'Valmix Porkkanadippi on tuore, noin 10 cm pitkä tikku. Oivallinen esimerkiksi välipalana tai lisäkkeenä.',
#     'language': 'fi'},
#    {'value': 'Valmix Morotsdipp är en färsch, ca 10 cm lång sticka. Utmärkt som till exempel mellanmål eller tillskott.',
#     'language': 'sv'}],
#   'names': [{'value': 'Valmix Carrot dip 10cm 2,5kg', 'language': 'en'},
#    {'value': 'Valmix Porkkanadippi 10cm 2,5kg', 'language': 'fi'},
#    {'value': 'Valmix Morotsdipp 10cm 2,5kg', 'language': 'sv'}],
#   'image': '/product_images/img_0573_4622851dfd.jpg'},
#  ...]
